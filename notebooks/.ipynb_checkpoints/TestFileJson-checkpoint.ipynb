# %%
import json
import boto3

# %%
s3 = boto3.client(
    's3',
    aws_access_key_id='test',  # LocalStack: test/test
    aws_secret_access_key='test',
    endpoint_url='http://localstack:4566'  # LocalStack S3 URL
)

# %%
bucket_name = 'youtube-trend-data'
object_key = 'raw/youtube_trending_batch_20250618_064645.json'

response = s3.get_object(Bucket=bucket_name, Key=object_key)
content = response['Body'].read().decode('utf-8')

# Đọc từng dòng JSON
data = [json.loads(line) for line in content.strip().split('\n')]

# %%
print(data[0])
# Out:
# {'id': 'de6UvFKbuZQ', 'title': 'Em Xinh Say Hi Tập 3: Đại chiến lập đội với màn đấu trí nghẹt thở, Dương Lâm đối đầu thế hệ cợt nhả', 'category_id': '10', 'category_name': 'Unknown', 'views': 6212494, 'likes': 74491, 'comments': 8250, 'region': 'VN', 'timestamp': '2025-06-18T06:45:14.583952'}

# %%
print(data)
# Out:
# [{'id': 'de6UvFKbuZQ', 'title': 'Em Xinh Say Hi Tập 3: Đại chiến lập đội với màn đấu trí nghẹt thở, Dương Lâm đối đầu thế hệ cợt nhả', 'category_id': '10', 'category_name': 'Unknown', 'views': 6212494, 'likes': 74491, 'comments': 8250, 'region': 'VN', 'timestamp': '2025-06-18T06:45:14.583952'}, {'id': 'KjflhsdN170', 'title': '$1 vs $1000 Water Gun!', 'category_id': '22', 'category_name': 'Unknown', 'views': 38558597, 'likes': 596243, 'comments': 733, 'region': 'VN', 'timestamp': '2025-06-18T06:45:14.695780'}, {'id': 'Ry1rYSCIfBg', 'title': 'Cách để uống trà sữa của em gái', 'category_id': '22', 'category_name': 'Unknown', 'views': 5857481, 'likes': 75280, 'comments': 195, 'region': 'VN', 'timestamp': '2025-06-18T06:45:14.798421'}, {'id': 'kBUre1NQ_K4', 'title': 'Test Sức Mạnh OCD Của ChiChi Với Hố Khổng Lồ ??! 🤣 - Tập 706 #shorts', 'category_id': '20', 'category_name': 'Unknown', 'views': 4800248, 'likes': 185747, 'comments': 817, 'region': 'VN', 'timestamp': '2025-06-18T06:45:14.888728'}, {'id': 'OqkU0MXEbx0', 'title': 'Watermelon Cappuccino assassino #shorts #YuliaBely', 'category_id': '24', 'category_name': 'Unknown', 'views': 23734526, 'likes': 570756, 'comments': 328, 'region': 'VN', 'timestamp': '2025-06-18T06:45:15.010363'}, {'id': 'eKDfG4JWTRg', 'title': '#头脑特工队#家庭#搞笑#可爱', 'category_id': '22', 'category_name': 'Unknown', 'views': 24605576, 'likes': 277281, 'comments': 248, 'region': 'VN', 'timestamp': '2025-06-18T06:45:15.108352'}, {'id': 'L6YZImsw-LE', 'title': 'When they forget noob in town ☠️ PT8 - Roblox Dead Rails #robloxanimation', 'category_id': '22', 'category_name': 'Unknown', 'views': 15410929, 'likes': 402043, 'comments': 1799, 'region': 'VN', 'timestamp': '2025-06-18T06:45:15.204150'}, {'id': '7wJ4fthapEU', 'title': 'Boneca Ambalabu đua xe với Báo và cái kết #shorts #cartoon #animation #ngaohoathinh', 'category_id': '1', 'category_name': 'Unknown', 'views': 6614910, 'likes': 103063, 'comments': 118, 'region': 'VN', 'timestamp': '2025-06-18T06:45:15.319657'}, {'id': 'FQW6LT0mbY0', 'title': 'Anh em mình chỉ trêu em thôi chứ bên ngoài nhìn em thương lắm #buidinhthuc #hanhquanxuyenviet', 'category_id': '22', 'category_name': 'Unknown', 'views': 1643316, 'likes': 30570, 'comments': 271, 'region': 'VN', 'timestamp': '2025-06-18T06:45:15.405948'}, {'id': '0cz35MGCo0Y', 'title': '4AM ơii #4amhairstudio #hairstyle #ciin', 'category_id': '22', 'category_name': 'Unknown', 'views': 3507280, 'likes': 83688, 'comments': 152, 'region': 'VN', 'timestamp': '2025-06-18T06:45:15.499009'}, {'id': 'm4Pi_KkMnvE', 'title': '好吓人啊还好是假的 #海贼王 #路飞', 'category_id': '22', 'category_name': 'Unknown', 'views': 58261513, 'likes': 621103, 'comments': 327, 'region': 'VN', 'timestamp': '2025-06-18T06:45:15.596603'}, {'id': 'p6BEWnZ_WjE', 'title': 'Em Xinh Say Hi Tập 2: 30 cực phẩm hội tụ - Đại chiến căng thẳng cùng 6 tiết mục dàn dựng công phu', 'category_id': '10', 'category_name': 'Unknown', 'views': 6576796, 'likes': 76757, 'comments': 13267, 'region': 'VN', 'timestamp': '2025-06-18T06:45:15.696509'}, {'id': 'Nlvol1_u778', 'title': 'What should I do if a child wants to swim without swimming rings?#Short #Officer Rabbit #angel', 'category_id': '22', 'category_name': 'Unknown', 'views': 50608523, 'likes': 574997, 'comments': 223, 'region': 'VN', 'timestamp': '2025-06-18T06:45:15.802020'}, {'id': 'AvEkjqyLyU0', 'title': 'How did Harley Quinn turn into a zombie#Harley Quinn #joker', 'category_id': '22', 'category_name': 'Unknown', 'views': 29142571, 'likes': 1058349, 'comments': 941, 'region': 'VN', 'timestamp': '2025-06-18T06:45:15.889420'}, {'id': 'tiXzFRY9aws', 'title': 'Con giúp cha là nhà có " BIẾN" P1 #xonhaBun #viral #comedy #trending #shorts', 'category_id': '22', 'category_name': 'Unknown', 'views': 2136258, 'likes': 17866, 'comments': 31, 'region': 'VN', 'timestamp': '2025-06-18T06:45:15.975720'}, {'id': 'SrgQXTUXbVI', 'title': 'Thứ vô địch mát nhất mùa hè kiểu', 'category_id': '24', 'category_name': 'Unknown', 'views': 2333657, 'lik ...

# %%
print(f"Số dòng: {len(data)}")
# Out:
# Số dòng: 150
